# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
crime_df = pd.read_csv("age_crime.csv")
crime_df
# Out:
#       Year Year ending      Sex          Age Group  \
# 0     2021    December  Females        10-14 years
# 1     2021    December  Females        10-14 years
# 2     2021    December  Females        10-14 years
# 3     2021    December  Females        10-14 years
# 4     2021    December  Females        10-14 years
# ...    ...         ...      ...                ...
# 1546  2012    December    Males  65 years and over
# 1547  2012    December    Males  65 years and over
# 1548  2012    December    Males  65 years and over
# 1549  2012    December    Males  65 years and over
# 1550  2012    December    Males  65 years and over
#
#                           Offence Division Alleged Offender Incidents
# 0              A Crimes against the person                        657
# 1        B Property and deception offences                        557
# 2                          C Drug offences                         21
# ...

# %%
cols = []
for col in crime_df.columns:
    cols.append(col)
    print(col)
# Out:
# Year
# Year ending
# Sex
# Age Group
# Offence Division
# Alleged Offender Incidents

# %%
crime_df["Alleged Offender Incidents"].describe()
# Out:
# count     1551
# unique    1005
# top          2
# freq        31
# Name: Alleged Offender Incidents, dtype: object

# %%
crime_df.dtypes
# Out:
# Year                           int64
# Year ending                   object
# Sex                           object
# Age Group                     object
# Offence Division              object
# Alleged Offender Incidents    object
# dtype: object

# %%
crime_df['Incidents_cleaned'] = crime_df['Alleged Offender Incidents']
crime_df["Incidents_cleaned"] = crime_df["Incidents_cleaned"].replace(",","", regex = True)
crime_df
# Out:
#       Year Year ending      Sex          Age Group  \
# 0     2021    December  Females        10-14 years
# 1     2021    December  Females        10-14 years
# 2     2021    December  Females        10-14 years
# 3     2021    December  Females        10-14 years
# 4     2021    December  Females        10-14 years
# ...    ...         ...      ...                ...
# 1546  2012    December    Males  65 years and over
# 1547  2012    December    Males  65 years and over
# 1548  2012    December    Males  65 years and over
# 1549  2012    December    Males  65 years and over
# 1550  2012    December    Males  65 years and over
#
#                           Offence Division Alleged Offender Incidents  \
# 0              A Crimes against the person                        657
# 1        B Property and deception offences                        557
# 2                          C Drug offences                         21
# ...

# %%
crime_df["Incidents_cleaned"].astype('float')
# Out:
# 0       657.0
# 1       557.0
# 2        21.0
# 3        53.0
# 4        47.0
#         ...
# 1546    321.0
# 1547     31.0
# 1548    165.0
# 1549    123.0
# 1550      8.0
# Name: Incidents_cleaned, Length: 1551, dtype: float64

# %%
crime_df.astype({'Incidents_cleaned':'float'})
# Out:
#       Year Year ending      Sex          Age Group  \
# 0     2021    December  Females        10-14 years
# 1     2021    December  Females        10-14 years
# 2     2021    December  Females        10-14 years
# 3     2021    December  Females        10-14 years
# 4     2021    December  Females        10-14 years
# ...    ...         ...      ...                ...
# 1546  2012    December    Males  65 years and over
# 1547  2012    December    Males  65 years and over
# 1548  2012    December    Males  65 years and over
# 1549  2012    December    Males  65 years and over
# 1550  2012    December    Males  65 years and over
#
#                           Offence Division Alleged Offender Incidents  \
# 0              A Crimes against the person                        657
# 1        B Property and deception offences                        557
# 2                          C Drug offences                         21
# ...

# %%
age_10_14_df = crime_df.loc[crime_df['Age Group'] == '10-14 years']
total_10_14 = age_10_14_df.groupby(['Year','Sex'])["Incidents_cleaned"].sum()

age_15_17_df = crime_df.loc[crime_df['Age Group'] == '15-17 years']
total_15_17 = age_15_17_df.groupby(['Year','Sex'])["Incidents_cleaned"].sum()

age_18_19_df = crime_df.loc[crime_df['Age Group'] == '18-19 years']
total_18_19 = age_15_17_df.groupby(['Year','Sex'])["Incidents_cleaned"].sum()

age_20_24_df = crime_df.loc[crime_df['Age Group'] == '20-24 years']
total_20_24 = age_20_24_df.groupby(['Year','Sex'])["Incidents_cleaned"].sum()

age_25_29_df = crime_df.loc[crime_df['Age Group'] == '25-29 years']
total_25_29 = age_25_29_df.groupby(['Year','Sex'])["Incidents_cleaned"].sum()

age_30_34_df = crime_df.loc[crime_df['Age Group'] == '30-34 years']
total_30_34 = age_30_34_df.groupby(['Year','Sex'])["Incidents_cleaned"].sum()

age_35_39_df = crime_df.loc[crime_df['Age Group'] == '35-39 years']
total_35_39 = age_35_39_df.groupby(['Year','Sex'])["Incidents_cleaned"].sum()

age_40_44_df = crime_df.loc[crime_df['Age Group'] == '40-44 years']
total_40_44 = age_40_44_df.groupby(['Year','Sex'])["Incidents_cleaned"].sum()

age_45_49_df = crime_df.loc[crime_df['Age Group'] == '45-49 years']
total_45_49 = age_45_49_df.groupby(['Year','Sex'])["Incidents_cleaned"].sum()

age_50_54_df = crime_df.loc[crime_df['Age Group'] == '50-54 years']
total_50_54 = age_50_54_df.groupby(['Year','Sex'])["Incidents_cleaned"].sum()

age_55_59_df = crime_df.loc[crime_df['Age Group'] == '55-59 years']
total_40_44 = age_40_44_df.groupby(['Year','Sex'])["Incidents_cleaned"].sum()

age_60_64_df = crime_df.loc[crime_df['Age Group'] == '60-64 years']
total_60_64 = age_60_64_df.groupby(['Year','Sex'])["Incidents_cleaned"].sum()

age_65_over_df = crime_df.loc[crime_df['Age Group'] == '65 years and over']
total_65_over = age_65_over_df.groupby(['Year','Sex'])["Incidents_cleaned"].sum()
